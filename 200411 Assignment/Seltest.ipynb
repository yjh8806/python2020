# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
import requests, time
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

# %%
url = 'https://movie.naver.com/movie/point/af/list.nhn'
response = urllib.request.urlopen(url)
soup = BeautifulSoup(response, 'html.parser')
print(soup.select('td.title'))
print(soup.title)
# Out:
# [<td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=186821&amp;target=after">정직한 후보</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:90%">별점 - 총 10점 중</span></span><em>9</em>
# </div>
# <br/>재밌음
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('king****', 'niE+2Qp1eJafju2b3uXb/c51QL0ejLoRcp/UxSm5F6Q=', '재밌음', '16814606', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=142304&amp;target=after">뚜르: 내 생애 최고의 49일</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>
# <br/>이영화 옛날에 어느 다음카페에 올라와있던 영상 아닌가요? 넷플릭스에 자전거라고 검색하니 나와서 봤는데 그영상같아서요 아시는분 ??
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('yaho****', 'E2lfUvzWwVlWn1J/odMy5MSM2ie9kHJEmXuDtjbHz5g=', '이영화 옛날에 어느 다음카페에 올라와있던 영상 아닌가요? 넷플릭스에 자전거라고 검색하니 나와서 봤는데 그영상같아서요 아시는분 ??', '16814605', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=179181&amp;target=after">지푸라기라도 잡고 싶은 짐승들</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:40%">별점 - 총 10점 중</span></span><em>4</em>
# </div>
# <br/>정말 그저그런 한국영화 중 하나
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('scsz****', '8B/FX0o+mk/qD696zkrbxWrVWJj/fqn4AjCEDSdtwCA=', '정말 그저그런 한국영화 중 하나', '16814604', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=189000&amp;target=after">나이브스 아웃</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>
# <br/>자신을 ‘미국인’이라고 칭하는 그들. 그들에게 법이란 자신들이 유리할땐 법치주의자가 되고  불리할땐 합리주의자가 되는 것.
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('rmsk****', 'WiCRkx565u/ZI9goh5b7/D0IyDjiqSttZAkm7LP5C1c=', '자신을 ‘미국인’이라고 칭하는 그들. 그들에게 법이란 자신들이 유리할땐 법치주의자가 되고  불리할땐 합리주의자가 되는 것. ', '16814603', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=88669&amp;target=after">그 시절, 우리가 좋아했던 소녀</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>
# <br/>난 재밌게 봤는디..평론가 이용철님90년대 사람들은 그시절 추억하면 안됩니까? 왜죠?미안하지만 이용철님 평론은 극히 잘못됐습니다.
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('dong****', 'NxyGec4r9htz5q4/lBGtz+KdWEiuPIa+4v8j6qyNbfo=', '난 재밌게 봤는디..평론가 이용철님90년대 사람들은 그시절 추억하면 안됩니까? 왜죠?미안하지만 이용철님 평론은 극히 잘못됐습니다.', '16814602', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=168050&amp;target=after">스타 이즈 본</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:40%">별점 - 총 10점 중</span></span><em>4</em>
# </div>
# <br/>그냥 줄거리가 별로 노래도 별로..
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('amy_****', 'R5uurGk4BSaJpi9ySC3k8PCZ4ENmJBuIVQ7gn8wbB/o=', '그냥 줄거리가 별로 노래도 별로..', '16814601', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=144965&amp;target=after">필그리미지</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:60%">별점 - 총 10점 중</span></span><em>6</em>
# </div>
# <br/>성물이 뭐길래. 의미를 담은 목표는 목적을 만들고 당위성을 만든다.
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('jamy****', 'EKZzfmjH+wuGCHEG3t6RGJ6ooakU/1gY3QnFrOhteMI=', '성물이 뭐길래. 의미를 담은 목표는 목적을 만들고 당위성을 만든다.', '16814600', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=144754&amp;target=after">선생님과 길고양이</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:80%">별점 - 총 10점 중</span></span><em>8</em>
# </div>
# <br/>동네의 길고양이의 상실을 통해 모든 생명의 숙명인 죽음은 무엇인가 또 다른이의 죽음을 경험하는 사람은 어떻게 받아들일것인가에 대해 생각하게 하는 잔잔한 영화네요.
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('eden****', 'WK77LOuprgQbLAGjjBdGC4xwzMdZUfBWlsoZahluAyA=', '동네의 길고양이의 상실을 통해 모든 생명의 숙명인 죽음은 무엇인가 또 다른이의 죽음을 경험하는 사람은 어떻게 받아들일것인가에 대해 생각하게 하는 잔잔한 영화네요.', '16814599', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=187321&amp;target=after">1917</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:10%">별점 - 총 10점 중</span></span><em>1</em>
# </div>
# <br/>깝OO들 떤다 어떡게하면 이 시국에 무슨 넷플릭스보단 영화관이 존재해야하는 이유라는 입방정을 털 수 있지? 사회적 거리두기한다고 온 국민이 고생을 감수하고 있는데 영화관에서 영화를 봐야한다는 개소리를 짖어대고 있네 에이 칵 퉤
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('jhsa****', 'PZsZtQEmth86ZgW04DiHmfAPTRPXBRi59vBgK3VqG7Q=', '깝지랄들 떤다 어떡게하면 이 시국에 무슨 넷플릭스보단 영화관이 존재해야하는 이유라는 입방정을 털 수 있지? 사회적 거리두기한다고 온 국민이 고생을 감수하고 있는데 영화관에서 영화를 봐야한다는 개소리를 짖어대고 있네 에이 칵 퉤', '16814598', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>, <td class="title">
# <a class="movie color_b" href="?st=mcode&amp;sword=187321&amp;target=after">1917</a>
# <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:90%">별점 - 총 10점 중</span></span><em>9</em>
# </div>
# <br/>집에서 유튜브로 결제해서 봤는데 왜 영화관에서 영화를 본거 같은 기분이 드는거죠?
#
#
#
#
#
#
# 				<a class="report" href="javascript:report('hyun****', 'Noa5Mah2QhsyjYWtPdEii/Up/zJsCbiOVO+W/Fnslg8=', '집에서 유튜브로 결제해서 봤는데 왜 영화관에서 영화를 본거 같은 기분이 드는거죠? ', '16814597', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
# </td>]
# <title>네티즌 평점 : 네이버 영화</title>

# %%
driver = webdriver.Remote("http://selenium:4444/wd/hub", DesiredCapabilities.CHROME/
driver.get('https://movie.naver.com/movie/point/af/list.nhn')

driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[1]/td[2]/a[1]')
source = driver.page_source
print(source)
# Out:
#   File "<ipython-input-14-64bfd5076d48>", line 4
#     driver.find_element_by_xpath('//*[@id="old_content"]/table/tbody/tr[1]/td[2]/a[1]')
#          ^
# SyntaxError: invalid syntax
