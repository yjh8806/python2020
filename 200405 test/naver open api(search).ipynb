# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "OMMTj_IqZvR6V7FLm6oy"
client_secret = "QquCS2Vt6a"
keywords = input("원하는 키워드를 입력하세요 : ")
encText = urllib.parse.quote(keywords)
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # &display, start 사용해서 출력 건수 지정
# ↑ json 결과 
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # .getcode()한 코드 번호가 200이라면
    response_body = response.read()
    print(response_body.decode('utf-8'))
    print(type(response_body)) # bytes 클래스
else:
    print("Error Code:" + rescode)
# Out:
# 원하는 키워드를 입력하세요 :  코로나
# {
# "lastBuildDate": "Sun, 05 Apr 2020 09:36:38 +0900",
# "total": 3801188,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>코로나</b> 긴급생계비지원 신청 정부지원금 기준은?",
# "link": "https:\/\/blog.naver.com\/dongi0508?Redirect=Log&logNo=221888066070",
# "description": "<b>코로나</b> 긴급생계비지원 신청 정부지원금 기준은? 오늘도 역시 요즘에 우리나라에서 시행하고 있는 각... 그치만 대부분 공통적인 것은 중위소득 100% 이하인 분들이 <b>코로나</b> 긴급생계비지원 신청 자격이... ",
# "bloggername": "Der Sinn des Lebens",
# "bloggerlink": "https://blog.naver.com/dongi0508",
# "postdate": "20200403"
#
# },
# {
# "title": "<b>코로나</b> 고용유지지원금 신청방법 알려드립니다",
# "link": "https:\/\/blog.naver.com\/gangkyongmo?Redirect=Log&logNo=221867301953",
# "description": "<b>코로나</b> 고용유지지원금 신청방법 알려드립니다 안녕하세요. 강경모 노무사 입니다. 오늘은 <b>코로나</b> 고용유지지원금 신청방법 글을 올리도록 하겠습니다. 요즘 전국적으로 엄청난 어려움을 겪고 있습니다.... ",
# "bloggername": "강노무사의 유쾌한 노동법",
# "bloggerlink": "https://blog.naver.com/gangkyongmo",
# "postdate": "20200322"
#
# },
# {
# "title": "<b>코로나</b>19 예방을 위한 실내 청소, 소독법",
# ...
