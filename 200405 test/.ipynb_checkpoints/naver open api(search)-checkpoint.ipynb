# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "OMMTj_IqZvR6V7FLm6oy"
client_secret = "QquCS2Vt6a"
keywords = input("원하는 키워드를 입력하세요 : ")
encText = urllib.parse.quote(keywords)
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # &display, start 사용해서 출력 건수 지정
# ↑ json 결과 
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # .getcode()한 코드 번호가 200이라면
    response_body = response.read()
    print(response_body.decode('utf-8'))
    print(type(response_body)) # bytes 클래스
else:
    print("Error Code:" + rescode)
# Out:
# 원하는 키워드를 입력하세요 :  코로나 19
# {
# "lastBuildDate": "Wed, 08 Apr 2020 15:49:44 +0900",
# "total": 2018667,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>코로나19</b> 예방을 위한 실내 청소, 소독법",
# "link": "https:\/\/blog.naver.com\/blood_info?Redirect=Log&logNo=221879369464",
# "description": "<b>코로나19</b>로 인해 실내에서 생활해야 하는 시간이 늘어났기에 실내 청소와 소독은 더욱 중요한 시기입니다. 오늘은 <b>코로나19</b>를 예방하기 위한 실내 청소와 소독법에 대하여 알아보겠습니다. 질병관리본부에서는... ",
# "bloggername": "헌혈로 나를 채우는 Red Storyㅣ대한적십자사",
# "bloggerlink": "https://blog.naver.com/blood_info",
# "postdate": "20200329"
#
# },
# {
# "title": "[3월 29일(일)] <b>코로나19</b> 고양시 발생 현황",
# "link": "https:\/\/blog.naver.com\/letsgoyang?Redirect=Log&logNo=221879164485",
# "description": "&lt;<b>코로나19</b> 고양시 현황&gt; 2020년 3월 29일(일) ✔️ 확진환자: 26명 (18명 입원, 8명 퇴원)... 음성 - <b>코로나19</b> 위기 농가 돕기 '친환경 농산물 드라이브 스루' 안심 판매 (~3.31(화) 오후 3시~6시... ",
# "bloggername": "고양시청 블로그",
# "bloggerlink": "https://blog.naver.com/letsgoyang",
# "postdate": "20200329"
#
# },
# {
# "title": "<b>코로나19</b> 예방 제대로모르면 위험합니다.",
# "link": "https:\/\/blog.naver.com\/lookbylook?Redirect=Log&logNo=221877106928",
# "description": "현재 하루 <b>코로나19</b> 확진자 증가량이 90~120명을 왔다갔다 하고 있습니다. 이 증가량이라면 1주일내에 우리나라 <b>코로나19</b> 확진자 1만명이 될 것으로 예상됩니다. 정부에서는 사회적 거리두기라는 강력한 권고를... ",
# "bloggername": "AIRPU.M",
# "bloggerlink": "https://blog.naver.com/lookbylook",
# "postdate": "20200328"
#
# },
# {
# "title": "<b>코로나19</b>, 서울시 『재난 긴급생활비』 지원 안내",
# "link": "https:\/\/blog.naver.com\/gangdongpr?Redirect=Log&logNo=221881281054",
# "description": "<b>코로나19</b>로 생계 위기에 처한 구민에게 '재난 긴급생활비'를 지원합니다. '지원 대상'과 '접수방법... ① <b>코로나19</b> 정부 지원 혜택가구 (국민기초수급자, 차상위, 아동수당, <b>코로나19</b>입원·자가격리자)... ",
# "bloggername": "강동구 공식블로그",
# "bloggerlink": "https://blog.naver.com/gangdongpr",
# "postdate": "20200330"
#
# },
# {
# "title": "<b>코로나19</b> 이겨내자! 영유아 실내 놀이 3종 세트!",
# "link": "https:\/\/blog.naver.com\/jinslovejin?Redirect=Log&logNo=221894884673",
# "description": "매번 <b>코로나19</b> 때문에 힘들다고 한다. 나도 확찐자가 되었다. 벌써 3kg 이상 쪘다. 매번 내일부터 다이어트를 하자고 다짐하지만, 저녁마다 무너진다. 살도 조금 뺄 겸, 아이들과 즐겁게 놀아볼 겸 해서 <b>코로나19</b>... ",
# "bloggername": "행복덩이 아빠의 즐거운 하루",
# "bloggerlink": "https://blog.naver.com/jinslovejin",
# "postdate": "20200407"
#
# },
# {
# "title": "<b>코로나19</b>, 재난긴급생활비 신청·접수 방법 확인하세요!",
# "link": "https:\/\/blog.naver.com\/pride_gb?Redirect=Log&logNo=221881566917",
# "description": "<b>코로나19</b> 경상북도 재난 긴급생활비 신청·접수 안내 도민 생계가 우선입니다! 위기 가구에 재난... 제외대상 가구 ▪ 긴급지원사업,실업급여 대상자 ▪ 저소득 한시 생활 지원 대상자 ▪ <b>코로나</b>-<b>19</b> 지역... ",
# "bloggername": "경상북도 공식블로그",
# "bloggerlink": "https://blog.naver.com/pride_gb",
# "postdate": "20200330"
#
# },
# {
# "title": "[<b>코로나19</b>]조금만 더 힘내자!",
# "link": "https:\/\/blog.naver.com\/shalacho?Redirect=Log&logNo=221891449857",
# "description": "원래도 잘 받지 않는 고객센터 전화인데 <b>코로나19</b>로 필수인력만 나와서 일을 하니 더 받지 않았을 터... <b>코로나19</b>로 고통스러워 하는 사람은 너무 많습니다. 저의 어머니도 평소 절반의 일만 하고 계시며 전에도... ",
# "bloggername": "보미 정리",
# "bloggerlink": "https://blog.naver.com/shalacho",
# "postdate": "20200405"
#
# },
# {
# "title": "존리 대표 - <b>코로나19</b> 위기, 변동성이 빨라졌을 뿐.",
# "link": "https:\/\/blog.naver.com\/yunvestor1?Redirect=Log&logNo=221892777281",
# "description": "존리 대표 - <b>코로나19</b> 위기, 변동성이 더 빨라졌을 뿐. 메리츠자산운용 존리 대표 <b>코로나19</b>... 삼성전자가 코로나 위기로 좀 어려울 수는 있겠지만, 각 나라가 봉쇄를 하니까. 반도체에 나쁜 영향이... ",
# "bloggername": "윤킴의 입장",
# "bloggerlink": "https://blog.naver.com/yunvestor1",
# "postdate": "20200406"
#
# },
# {
# "title": "자주 하는 질문! QnA <b>코로나19</b> 정부 정책 확인해 보세요!!",
# "link": "https:\/\/blog.naver.com\/ocublog?Redirect=Log&logNo=221888899110",
# "description": "#긴급재난지원금 #<b>코로나19</b>재난지원금 #자주묻는질문 #QnA 안녕하세요. 한국열린사이버대학교 입니다. <b>코로나19</b> 사태가 지속되는 만큼 정부의 긴급 지원 정책도 늘어나고 있는데요 최근 3차... ",
# "bloggername": "200만이 선택한 한국열린사이버대학교",
# "bloggerlink": "https://blog.naver.com/ocublog",
# "postdate": "20200403"
#
# },
# {
# "title": "<b>코로나19</b> 남양주시 재난긴급지원금 관련 브리핑",
# "link": "https:\/\/blog.naver.com\/nyjloving?Redirect=Log&logNo=221896911349",
# "description": "존경하는 남양주 시민 여러분, <b>코로나19</b> 사태로 인해 얼마나 힘이 드십니까. 답답함과 어려움... <b>코로나</b>-<b>19</b> 사태로 인해 어려움을 겪고 계신 분들께 실질적인 도움을 드려야 한다는 절박함이 있었습니다.... ",
# "bloggername": "남양주시 블로그",
# "bloggerlink": "https://blog.naver.com/nyjloving",
# "postdate": "20200408"
#
# }
# ]
# }
#
# <class 'bytes'>
